# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PowerTransformer, StandardScaler, OneHotEncoder
from imblearn.over_sampling import SMOTE


# load the data
df = pd.read_csv('../data/customer_churn_data.csv',index_col=0)

# %%
# separate the features and target variable
X = df.drop('Attrition_Flag', axis=1)
y = df['Attrition_Flag']

    # get the list of numerical features
num_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

    # normalize skewed features with PowerTransformer
pt = PowerTransformer()
X[num_cols] = pt.fit_transform(X[num_cols])

    # scale features with StandardScaler
scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# %%
# one hot encode categorical features
encoder = OneHotEncoder(handle_unknown='ignore')
X_cat = encoder.fit_transform(X.select_dtypes(include=['object']))

# %%
X.isna()
# Out:
#            Customer_Age  Gender  Dependent_count  Education_Level  \
# CLIENTNUM
# 768805383         False   False            False            False
# 818770008         False   False            False            False
# 713982108         False   False            False            False
# 769911858         False   False            False            False
# 709106358         False   False            False            False
# ...                 ...     ...              ...              ...
# 772366833         False   False            False            False
# 710638233         False   False            False            False
# 716506083         False   False            False            False
# 717406983         False   False            False            False
# 714337233         False   False            False            False
#
#            Marital_Status  Income_Category  Card_Category  Months_on_book  \
# CLIENTNUM
# 768805383           False            False          False           False
# 818770008           False            False          False           False
# 713982108           False            False          False           False
# 769911858           False            False          False           False
# 709106358           False            False          False           False
# ...                   ...              ...            ...             ...
# 772366833           False            False          False           False
# 710638233           False            False          False           False
# 716506083           False            False          False           False
# 717406983           False            False          False           False
# 714337233           False            False          False           False
#
#            Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# 768805383                     False                   False
# 818770008                     False                   False
# 713982108                     False                   False
# 769911858                     False                   False
# 709106358                     False                   False
# ...                             ...                     ...
# 772366833                     False                   False
# 710638233                     False                   False
# 716506083                     False                   False
# 717406983                     False                   False
# 714337233                     False                   False
#
#            Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# CLIENTNUM
# 768805383                  False         False                False
# 818770008                  False         False                False
# 713982108                  False         False                False
# 769911858                  False         False                False
# 709106358                  False         False                False
# ...                          ...           ...                  ...
# 772366833                  False         False                False
# 710638233                  False         False                False
# 716506083                  False         False                False
# 717406983                  False         False                False
# 714337233                  False         False                False
#
#            Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# CLIENTNUM
# 768805383            False                 False            False
# 818770008            False                 False            False
# 713982108            False                 False            False
# 769911858            False                 False            False
# 709106358            False                 False            False
# ...                    ...                   ...              ...
# 772366833            False                 False            False
# 710638233            False                 False            False
# 716506083            False                 False            False
# 717406983            False                 False            False
# 714337233            False                 False            False
#
#            Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# CLIENTNUM
# 768805383           False                False                  False
# 818770008           False                False                  False
# 713982108           False                False                  False
# 769911858           False                False                  False
# 709106358           False                False                  False
# ...                   ...                  ...                    ...
# 772366833           False                False                  False
# 710638233           False                False                  False
# 716506083           False                False                  False
# 717406983           False                False                  False
# 714337233           False                False                  False
#
# [10127 rows x 19 columns]

# %%
X = pd.join([pd.DataFrame(X[num_cols]), pd.DataFrame(X_cat.toarray())], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 X = pd.join([pd.DataFrame(X[num_cols]), pd.DataFrame(X_cat.toarray())], axis=1)
#
# File ~/miniconda3/envs/datascience/lib/python3.10/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'join'
