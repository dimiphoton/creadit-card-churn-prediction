# %%
import helper
helper.test()
import os
os.getcwd()
import sys
sys.path.append("..")
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ok

# %%
data=helper.DataProcessor()

# %%
data.transform2(data.X_test)

# %%
data.X_test
# Out:
#            Customer_Age Gender  Dependent_count Education_Level  \
# CLIENTNUM
# 719455083            48      F                3      Uneducated
# 773503308            59      M                1      Uneducated
# 715452408            37      F                2        Graduate
# 711264033            47      M                3       Doctorate
# 718943508            42      M                3         Unknown
# ...                 ...    ...              ...             ...
# 788771733            49      M                4     High School
# 712341933            39      M                1        Graduate
# 716989683            56      M                2       Doctorate
# 711957708            38      F                2        Graduate
# 787348608            70      M                0     High School
#
#           Marital_Status Income_Category Card_Category  Months_on_book  \
# CLIENTNUM
# 719455083         Single  Less than $40K          Blue              39
# ...

# %%
preprocessor = ColumnTransformer(transformers=[('num', data.scaler, data.num_cols)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 preprocessor = ColumnTransformer(transformers=[('num', data.scaler, data.num_cols)])
#
# NameError: name 'ColumnTransformer' is not defined

# %%
data.X_test
# Out:
#            Customer_Age Gender  Dependent_count Education_Level  \
# CLIENTNUM
# 719455083            48      F                3      Uneducated
# 773503308            59      M                1      Uneducated
# 715452408            37      F                2        Graduate
# 711264033            47      M                3       Doctorate
# 718943508            42      M                3         Unknown
# ...                 ...    ...              ...             ...
# 788771733            49      M                4     High School
# 712341933            39      M                1        Graduate
# 716989683            56      M                2       Doctorate
# 711957708            38      F                2        Graduate
# 787348608            70      M                0     High School
#
#           Marital_Status Income_Category Card_Category  Months_on_book  \
# CLIENTNUM
# 719455083         Single  Less than $40K          Blue              39
# ...

# %%
data.transform()

# %%
from sklearn.cluster import KMeans
# create a KMeans clustering model with k clusters
k = 3
model = KMeans(n_clusters=k, random_state=42)
model.fit(data.X_train)
# Out:
# /home/dimi/miniconda3/envs/datascience/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
# get the centroids of the KMeans clusters
centroids = model.cluster_centers_
# create a new dataframe with the centroid coordinates and column names

centroids_df = pd.DataFrame(centroids, columns=data.X_train.columns)

# %%
centroids_df
# Out:
#    Customer_Age  Dependent_count  Months_on_book  Total_Relationship_Count  \
# 0     -0.015995        -0.006439       -0.020476                  0.002919
# 1      0.066100         0.005614        0.050112                 -0.226450
# 2      0.035637         0.163546        0.024204                 -0.279859
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                0.030384              -0.023316     -0.446007
# 1                0.271383               0.373380     -0.389613
# 2                0.080905               0.221326      1.938015
#
#    Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  ...  \
# 0             0.681249        -0.507492              0.021764  ...
# 1            -1.158124        -0.285865             -0.284134  ...
# 2            -0.140870         1.951977              0.008458  ...
#
#    Marital_Status_Single  Marital_Status_Unknown  Income_Category_$40K - $60K  \
# ...

# %%
import matplotlib.pyplot as plt

# get the cluster labels for each point in X_train
labels = model.predict(X_train)

# create a scatter plot of the two most important features
feature1 = 'Total_Trans_Amt'
feature2 = 'Total_Trans_Ct'
plt.scatter(X_train[feature1], X_train[feature2], c=labels, cmap='viridis')
plt.xlabel(feature1)
plt.ylabel(feature2)
plt.title(f'{k}-Means Clustering')
plt.show()
